# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing data

# %%
# creating path
path = r'/Users/martyna/Documents/CF Data Analysis/Data Immersion/Acheivement 4/Instacart Basket Analysis 6.22'

# %%
# importing data
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_altered.pkl'))

# %%
# create a subset
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 22)

# %%
df.head(10)
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             1             1   2398795        1             2
# 2             2             2    473747        1             3
# 3             3             3   2254736        1             4
# 4             4             4    431534        1             5
# 5             5             5   3367565        1             6
# 6             6             6    550135        1             7
# 7             7             7   3108588        1             8
# 8             8             8   2295261        1             9
# 9             9             9   2550362        1            10
#
#    orders_days_of_week  order_hour_of_day  days_since_last_order  \
# 0                    2                  8                    NaN
# 1                    3                  7                   15.0
# 2                    3                 12                   21.0
# ...

# %%
# group by product name
df.groupby('product_name')

# %%
# group by department id and average order number
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
# performing multiple aggregations
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %%
# flag loyal customers
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0              0             0   2539329        1             1
# 1              1             1   2398795        1             2
# 2              2             2    473747        1             3
# 3              3             3   2254736        1             4
# 4              4             4    431534        1             5
# 5              5             5   3367565        1             6
# 6              6             6    550135        1             7
# 7              7             7   3108588        1             8
# 8              8             8   2295261        1             9
# 9              9             9   2550362        1            10
# 10           144           144   2968173       15            15
# 11           146           146   1870022       15            17
# 12           147           147   1911383       15            18
# 13           150           150   2715276       15            21
# ...

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0              0             0   2539329        1             1
# 1              1             1   2398795        1             2
# 2              2             2    473747        1             3
# 3              3             3   2254736        1             4
# 4              4             4    431534        1             5
# ..           ...           ...       ...      ...           ...
# 95          5895          5895   3226575      360             1
# 96          6137          6137   1469869      377             3
# 97          6259          6259   1927023      387             2
# 98          6740          6740    858092      420             4
# 99          6741          6741    119314      420             5
#
#     orders_days_of_week  order_hour_of_day  days_since_last_order  \
# 0                     2                  8                    NaN
# ...

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0              0             0   2539329        1             1
# 1              1             1   2398795        1             2
# 2              2             2    473747        1             3
# 3              3             3   2254736        1             4
# 4              4             4    431534        1             5
# 5              5             5   3367565        1             6
# 6              6             6    550135        1             7
# 7              7             7   3108588        1             8
# 8              8             8   2295261        1             9
# 9              9             9   2550362        1            10
# 10           144           144   2968173       15            15
# 11           146           146   1870022       15            17
# 12           147           147   1911383       15            18
# 13           150           150   2715276       15            21
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# ...

# %% [markdown]
# # TASK

# %%
# group by product name
ords_prods_merge.groupby('product_name')

# %%
# performing multiple aggregations
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.457838   1  99
# 2                17.277920   1  99
# 3                17.170395   1  99
# 4                17.811403   1  99
# 5                15.215751   1  99
# 6                16.439806   1  99
# 7                17.225802   1  99
# 8                15.340650   1  99
# 9                15.895474   1  99
# 10               20.197148   1  99
# 11               16.170638   1  99
# 12               15.887671   1  99
# 13               16.583536   1  99
# 14               16.773669   1  99
# 15               16.165037   1  99
# 16               17.665606   1  99
# 17               15.694469   1  99
# 18               19.310397   1  99
# 19               17.177343   1  99
# 20               16.473447   1  99
# 21               22.902379   1  99

# %%
# loyalty flags see above cells 10-20

# %%
# basic statistics
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# The averages are pretty similar, differing only by a few points. Considering how large the dataframe is, the subset was a relatively accurate representation of the whole.

# %%
# flag low vs high spenders
ords_prods_merge.groupby('user_id').agg({'prices': ['mean', 'min', 'max']}).head(5)
# Out:
#            prices
#              mean  min   max
# user_id
# 1        6.367797  1.0  14.0
# 2        7.515897  1.3  14.8
# 3        8.197727  1.3  14.4
# 4        8.205556  1.4  14.6
# 5        9.189189  3.2  14.8

# %%
ords_prods_merge['spending'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.loc[ords_prods_merge['spending'] < 10, 'spending_flag'] = 'Low Spender'

# %%
ords_prods_merge.loc[ords_prods_merge['spending'] >= 10, 'spending_flag'] = 'High Spender'

# %%
ords_prods_merge[['user_id', 'spending_flag', 'spending']].head(15)
# Out:
#     user_id spending_flag  spending
# 0         1   Low Spender  6.367797
# 1         1   Low Spender  6.367797
# 2         1   Low Spender  6.367797
# 3         1   Low Spender  6.367797
# 4         1   Low Spender  6.367797
# 5         1   Low Spender  6.367797
# 6         1   Low Spender  6.367797
# 7         1   Low Spender  6.367797
# 8         1   Low Spender  6.367797
# 9         1   Low Spender  6.367797
# 10       15   Low Spender  3.980556
# 11       15   Low Spender  3.980556
# 12       15   Low Spender  3.980556
# 13       15   Low Spender  3.980556
# 14       15   Low Spender  3.980556

# %%
# flag frequent vs nonfrequent customers
ords_prods_merge['frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_last_order'].transform(np.median)

# %%
ords_prods_merge.loc[ords_prods_merge['frequency'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['frequency'] <= 20) & (ords_prods_merge['frequency'] > 10), 'frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['frequency'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge[['user_id', 'frequency', 'frequency_flag']].head(15)
# Out:
#     user_id  frequency         frequency_flag
# 0         1       20.5  Non-frequent customer
# 1         1       20.5  Non-frequent customer
# 2         1       20.5  Non-frequent customer
# 3         1       20.5  Non-frequent customer
# 4         1       20.5  Non-frequent customer
# 5         1       20.5  Non-frequent customer
# 6         1       20.5  Non-frequent customer
# 7         1       20.5  Non-frequent customer
# 8         1       20.5  Non-frequent customer
# 9         1       20.5  Non-frequent customer
# 10       15       10.0      Frequent customer
# 11       15       10.0      Frequent customer
# 12       15       10.0      Frequent customer
# 13       15       10.0      Frequent customer
# 14       15       10.0      Frequent customer

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_updated.pkl'))
