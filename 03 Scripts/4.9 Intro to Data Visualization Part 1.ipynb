# %% [markdown]
# # Import libraries and data

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
# define path
path = r'/Users/martyna/Documents/CF Data Analysis/Data Immersion/Acheivement 4/Instacart Basket Analysis 6.22'

# %%
# import data
df_cust = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'), index_col = False)

# %%
# check shape
df_cust.shape
# Out:
# (206209, 10)

# %%
df_cust.head(10)
# Out:
#    user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# 5   133128    Cynthia     Noble  Female        Kentucky   43    1/1/2017
# 6   152052      Chris    Walton    Male         Montana   20    1/1/2017
# 7   168851     Joseph   Hickman    Male  South Carolina   30    1/1/2017
# 8    69965     Jeremy      Vang    Male           Texas   47    1/1/2017
# 9    82820      Shawn     Chung    Male        Virginia   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# ...

# %% [markdown]
# # Wrangling data

# %%
# rename columns
df_cust.rename(columns = {'Surnam':'last_name'}, inplace = True)

# %%
df_cust.rename(columns = {'First Name':'first_name'}, inplace = True)

# %%
df_cust.rename(columns = {'Gender':'gender'}, inplace = True)

# %%
df_cust.rename(columns = {'STATE':'state'}, inplace = True)

# %%
df_cust.rename(columns = {'Age':'age'}, inplace = True)

# %%
df_cust.rename(columns = {'n_dependants':'#_of_dependents'}, inplace = True)

# %%
df_cust.rename(columns = {'fam_status':'marital_status'}, inplace = True)

# %%
df_cust.head(10)
# Out:
#    user_id first_name last_name  gender           state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# 5   133128    Cynthia     Noble  Female        Kentucky   43    1/1/2017
# 6   152052      Chris    Walton    Male         Montana   20    1/1/2017
# 7   168851     Joseph   Hickman    Male  South Carolina   30    1/1/2017
# 8    69965     Jeremy      Vang    Male           Texas   47    1/1/2017
# 9    82820      Shawn     Chung    Male        Virginia   26    1/1/2017
#
#    #_of_dependents marital_status  income
# 0                3        married  165665
# 1                0         single   59285
# ...

# %% [markdown]
# # Consistency checks

# %%
# checking for duplicates
df_cust[df_cust.duplicated()]
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, last_name, gender, state, age, date_joined, #_of_dependents, marital_status, income]
# Index: []

# %%
# checking for missing values
df_cust.isnull().sum()
# Out:
# user_id                0
# first_name         11259
# last_name              0
# gender                 0
# state                  0
# age                    0
# date_joined            0
# #_of_dependents        0
# marital_status         0
# income                 0
# dtype: int64

# %%
# view missing values in first_name column

df_missing_fn = df_cust[df_cust['first_name'].isnull() == True]

# %%
df_missing_fn
# Out:
#         user_id first_name last_name  gender         state  age date_joined  \
# 53        76659        NaN   Gilbert    Male      Colorado   26    1/1/2017
# 73        13738        NaN     Frost  Female     Louisiana   39    1/1/2017
# 82        89996        NaN    Dawson  Female        Oregon   52    1/1/2017
# 99        96166        NaN   Oconnor    Male      Oklahoma   51    1/1/2017
# 105       29778        NaN    Dawson  Female          Utah   63    1/1/2017
# ...         ...        ...       ...     ...           ...  ...         ...
# 206038   121317        NaN    Melton    Male  Pennsylvania   28   3/31/2020
# 206044   200799        NaN  Copeland  Female        Hawaii   52    4/1/2020
# 206090   167394        NaN     Frost  Female        Hawaii   61    4/1/2020
# 206162   187532        NaN     Floyd  Female    California   39    4/1/2020
# 206171   116898        NaN   Delgado  Female      Colorado   23    4/1/2020
#
#         #_of_dependents marital_status  income
# ...

# %%
# create new df without first_name to check for duplicates

df_wo_fn = df_cust.drop(columns=['first_name'], axis=1)

# %%
df_wo_fn.head()
# Out:
#    user_id last_name  gender       state  age date_joined  #_of_dependents  \
# 0    26711  Esquivel  Female    Missouri   48    1/1/2017                3
# 1    33890      Hart  Female  New Mexico   36    1/1/2017                0
# 2    65803    Farley    Male       Idaho   35    1/1/2017                2
# 3   125935     Hicks  Female        Iowa   40    1/1/2017                0
# 4   130797   Gilmore  Female    Maryland   26    1/1/2017                1
#
#   marital_status  income
# 0        married  165665
# 1         single   59285
# 2        married   99568
# 3         single   42049
# 4        married   40374

# %%
df_wo_fn[df_wo_fn.duplicated()]
# Out:
# Empty DataFrame
# Columns: [user_id, last_name, gender, state, age, date_joined, #_of_dependents, marital_status, income]
# Index: []

# %% [markdown]
# no duplicates found, entries with missing first names remain in df

# %%
# check for mixed data types

# %%
for col in df_cust.columns.tolist():
  weird = (df_cust[[col]].applymap(type) != df_cust[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_cust[weird]) > 0:
    print (col)
# Out:
# first_name

# %%
df_cust['first_name'].dtype
# Out:
# dtype('O')

# %%
# reassign first name to string
df_cust['first_name'] = df_cust['first_name'].astype('str')

# %%
for col in df_cust.columns.tolist():
  weird = (df_cust[[col]].applymap(type) != df_cust[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_cust[weird]) > 0:
    print (col)

# %%
df_cust.dtypes
# Out:
# user_id             int64
# first_name         object
# last_name          object
# gender             object
# state              object
# age                 int64
# date_joined        object
# #_of_dependents     int64
# marital_status     object
# income              int64
# dtype: object

# %%
df_cust.head()
# Out:
#    user_id first_name last_name  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    #_of_dependents marital_status  income
# 0                3        married  165665
# 1                0         single   59285
# 2                2        married   99568
# 3                0         single   42049
# 4                1        married   40374

# %% [markdown]
# # Combine with Instacart data

# %%
# Import ords_prods_merge data

ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_updated.pkl'))

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             1             1   2398795        1             2
# 2             2             2    473747        1             3
# 3             3             3   2254736        1             4
# 4             4             4    431534        1             5
#
#    orders_days_of_week  order_hour_of_day  days_since_last_order  \
# 0                    2                  8                    NaN
# 1                    3                  7                   15.0
# 2                    3                 12                   21.0
# 3                    4                  7                   29.0
# 4                    4                 15                   28.0
#
#    new_customer  product_id  ...    price_range_loc     busiest_day  \
# 0          True         196  ...  Mid-range product  Regularly busy
# ...

# %%
ords_prods_merged =ords_prods_merge.drop(columns=['Unnamed: 0.1', 'Unnamed: 0_x'], axis=1)

# %%
ords_prods_merged.head(10)
# Out:
#    order_id  user_id  order_number  orders_days_of_week  order_hour_of_day  \
# 0   2539329        1             1                    2                  8
# 1   2398795        1             2                    3                  7
# 2    473747        1             3                    3                 12
# 3   2254736        1             4                    4                  7
# 4    431534        1             5                    4                 15
# 5   3367565        1             6                    2                  7
# 6    550135        1             7                    1                  9
# 7   3108588        1             8                    1                 14
# 8   2295261        1             9                    1                 16
# 9   2550362        1            10                    4                  8
#
#    days_since_last_order  new_customer  product_id  add_to_cart_order  \
# 0                    NaN          True         196                  1
# ...

# %%
# check user_id data type
ords_prods_merged['user_id'].dtype
# Out:
# dtype('int64')

# %%
# merge on user_id
df_full_merge = ords_prods_merged.merge(df_cust, on = 'user_id')

# %%
df_full_merge.shape
# Out:
# (32404859, 35)

# %%
df_full_merge.head(10)
# Out:
#    order_id  user_id  order_number  orders_days_of_week  order_hour_of_day  \
# 0   2539329        1             1                    2                  8
# 1   2398795        1             2                    3                  7
# 2    473747        1             3                    3                 12
# 3   2254736        1             4                    4                  7
# 4    431534        1             5                    4                 15
# 5   3367565        1             6                    2                  7
# 6    550135        1             7                    1                  9
# 7   3108588        1             8                    1                 14
# 8   2295261        1             9                    1                 16
# 9   2550362        1            10                    4                  8
#
#    days_since_last_order  new_customer  product_id  add_to_cart_order  \
# 0                    NaN          True         196                  1
# ...

# %%
# export
df_full_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'full_merge.pkl'))
